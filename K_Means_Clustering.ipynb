# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjeev00001/Machine-Learning-2/blob/main/K_Means_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
# !pip install scikit-learn-extra
from sklearn_extra.cluster import KMedoids

# generate synthetic data using make_blobs
X, y = make_blobs(n_samples=300, centers=4, random_state=42)
#appl K-Medoids algorithms
k = 4
kmedoids = KMedoids(n_clusters=k, random_state=42)
kmedoids.fit(X)
#get the medoids and labels
medoids = kmedoids.cluster_centers_
labels = kmedoids.labels_

# plot the  results
plt.scatter(X[:,0],X[:, 1], c= labels, s=50, cmap='viridis')
plt.scatter(medoids[:,0], medoids[:,1], c='red', s=200, alpha=0.75, marker='x')
plt.title('K-Medoids Clustering(using KMdiods library)')
plt.show()

# %%
#
